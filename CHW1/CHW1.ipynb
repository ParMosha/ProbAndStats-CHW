# %% [markdown]
# # __CHW1__
# ### <span style="color:purple;"> __StudentID:__</span> (enter your student ID here)
# ---

# %% [markdown]
# Please save all the files including the notebook file and other files as `Prob&Stats_CHW1_STUDENTNUMBER.zip` and complete the following sections as described in the `CHW1.ipynb` notebook.<br>
# Blue sections are <span style="color: #2791E8;">Theorical Questions</span> that need to be answerd in markdowns or in a seperated pdf file and Green sections are <span style="color: #27E860;"> Applied Questions</span> that need to be simulated based on the given description.<br>
# The GitHub link for the class is [here](https://github.com/ParMosha/ProbAndStats-CHW).

# %%
# Run the following code to import the necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### <span style="color: #2791E8;"> Theorical Question 1 :</span>
#
# ---
# If there are $n$ people in a room, what is the chance that some pair among them have the same birthday?
#
# If there are $n$ people in a room, what is the chance that there exists 3 people such that they have the same birthday?
#
# ---

# %% [markdown]
# #### <span style="color: #27E860;"> Applied Question 1 :</span>
#
# ---
# Write a function `n_birthdates` which returns an array of $n$ random birthdates.
#
# Then write a function `has_duplicates` which takes an array and returns `True` if there are duplicates in the array, `False` otherwise.
#
# Write a function `chance_of_duplicates` which takes $n$ as parameter and returns the probability of having a duplicate in the $n$ birthdates array.
#
# Then simulate the probability of having a duplicate for $n=[1,2,...,100]$ and plot the results.
#
#
# repeat the same steps for the case of 3 people having the same birthday.
#
# ---

# %%
def n_birthdates():
    # Write your code here
    # Use np.random.uniform() to generate a random point in the unit square





    
    return array

def has_duplicates(array):
    # Write your code here






    
    return has_duplicate

def chance_of_duplicates(n):
    # Write your code here
    # Use has_duplicates() to check if there are duplicates in the array generated by n_birthdates()





    
    return probability

def has_3_with_same_birthdays(array):
    # Write your code here






    
    return has_3_with_same_birthdays

def chance_of_3_with_same_birthdays(n):
    # Write your code here
    # Use has_3_with_same_birthdays() to check if there are 3 people with the same birthday in the array generated by n_birthdates()





    
    return probability

# %%
# Test your function by plotting the result and printing the wanted values

# Write your code here
#------------------------------------------------------------






# End of code
#------------------------------------------------------------

# %% [markdown]
# #### <span style="color: #2791E8;"> Theorical Question 2 :</span>
#
# ---
# A random number generator produces $2k+1$ digits so that all the numbers are equally likely.
#
# What is the chance that the digits are in the ascending order?
#
# What is the probability that the even digits appear in the first $k$ digits and the odd digits appear in the last $k+1$ digits?
#
# What is the probability that the sum of the all digits is divisible by $2k$?
#
# Whats the probability that the number contructed by the first $k$ digits devises the number constructed by the last $k+1$ digits?
#
# ---

# %% [markdown]
# #### <span style="color: #27E860;"> Applied Question 2 :</span>
#
# ---
# Write a function `random_digit` which returns an random digit.
#
# Then write a function `random_number` which takes an integer $n$ and returns a $n$ digit integer.
#
# Write a function `random_numebr_array` which takes $k$ and $n$ as parameter and returns an array the lengh of $k$ filled with $n$ digit numbers.
#
# Write a function `count_ascending` which takes an array and returns the number of integers in that array that have ascending digits.
#
# Write a function `count_divisible` which takes an array and returns the number of integers in that array that have the divisble constraints in the last part of the theorical question 2.
#
# Then simulate the probability of each part in the theorical question 2 for $k=[100,1000,10000]$ and <br> $n=[1,2,...,100]$ and plot the probability againts $n$ (there should be a plot for each value of $k$).
#
# `You can use either of the formats bellow for the first 5 parts doing both and using both formats to do the last part will have five parts worth of extra score that will only be applied on this CHW.`
#
# ---

# %%
#Format 1 (defining a class)

class RandomNumberSimulator:
    def __init__(self):
        pass
    
    def random_digit(self):
        # Write your code here
        # Use np.random.randint()






        return digit
    
    def random_number(self, n):
        # Write your code here
        # Use random_digit() to generate a random number of n digits






        return number
    
    def random_number_array(self, k, n):
        # Write your code here
        # Use random_number() to generate an array of k random numbers of n digits







        return array
    
    def is_ascending(self, num):
        # Write your code here
        # Use np.sort() to sort the digits of the number
        





        return isSorted
    
    def count_ascending(self, array):
        # Write your code here
        # Use is_ascending() to check if the number is ascending in the array generated by random_number_array()







        return count
    
    def count_divisible(self, array, k):
        # Write your code here
        # Use np.mod() to check if the number is divisible by k in the array generated by random_number_array()
        
        




        return count

# %%
#Format 2 (defining functions)
def random_digit():
    # Write your code here
    # Use np.random.randint()






    return digit

def random_number(n):
    # Write your code here
    # Use random_digit() to generate a random number of n digits






    return number

def random_number_array(k, n):
    # Write your code here
    # Use random_number() to generate an array of k random numbers of n digits







    return array

def is_ascending(num):
    # Write your code here
    # Use np.sort() to sort the digits of the number
    





    return isSorted

def count_ascending(array):
    # Write your code here
    # Use is_ascending() to check if the number is ascending in the array generated by random_number_array()







    return count

def count_divisible(array, k):
    # Write your code here
    # Use np.mod() to check if the number is divisible by k in the array generated by random_number_array()
    
    




    return count

# %%
# Test your function by plotting the result and printing the wanted values

# Write your code here
#------------------------------------------------------------












# End of code
#------------------------------------------------------------

# %% [markdown]
# #### <span style="color: #2791E8;"> Theorical Question 3 :</span>
#
# ---
#
# In the letter-envelope setting there are n letters labeled 1 through n and also n envelopes labeled 1 through n. The letters are permuted randomly into the envelopes, one letter per envelope (a mishap usually blamed on an unfortunate hypothetical secretary), so that all permutations are equally likely. The main questions are about the number of letters that are placed into their matching envelopes(number of fixed pointes).
#
# In the language of random variables, let $M_n$ be the number of fixed points (matches) in a random permutation of n elements.
#
# Find:
# $$P(M_n=k)$$
#
# Know that for large n , the distribution of $M_n$ is approximately Poisson with parameter 1 or in other words:
# $$P(M_n=k) ≈ \frac{1}{k!}e^{-1}$$
# And use this information for checking your results in the Apllied part.
#
# ---

# %% [markdown]
# #### <span style="color: #27E860;"> Applied Question 3 :</span>
#
# ---
# Write a function `random_permutation` which returns a random permutation of $n$ elements.
#
# Write a function `fixed_points` which takes an array and returns the number of fixed points in that array.
#
# Write a function `chance_of_fixed_points` which takes $n$ and $k$ as parameter and returns the probability of having $k$ fixed points in the $n$ element permutation.
#
# Then simulate the probability of having $k$ fixed points for $n=[23,230,2300]$ and plot the results.
#
# ---

# %%
def random_permutation(n):
    # Write your code here
    # Use np.random.permutation() to generate a random permutation of n elements







    return array
def fixed_points(array):
    # Write your code here
    # Use np.arange() to generate an array of n elements
    # Use np.sum() to count the number of fixed points in the array generated by random_permutation()







    return count

def chance_of_fixed_points(n,k):
    # Write your code here
    # Use fixed_points() to count the number of fixed points in the array generated by random_permutation()








    return probability

# %%
# Test your function by plotting the result and printing the wanted values

# Write your code here
#------------------------------------------------------------












# End of code
#------------------------------------------------------------
